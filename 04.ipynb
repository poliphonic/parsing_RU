# %%
import requests
from bs4 import BeautifulSoup as bs
from time import sleep
from pprint import pprint

# %%
headers = {
    'User-Agent': 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

# %%
def parse_hh(url, headers, pages=[], index_page=1):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return pages

    soup = bs(response.content, 'html.parser')
    vacancies = soup.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
        pages.append(parse_vacancy_hh(vacancy))

    link_next_page = soup.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
        link_next_page =  'https://spb.hh.ru' + link_next_page['href']
    else:
        return pages

    pages = parse_hh(link_next_page, headers, pages, index_page + 1)   
    return pages
     
def parse_vacancy_hh(vacancy):
    sleep(.1)
    name = vacancy.find('a').text

    salary = vacancy.find('span', {'class', 'bloko-header-section-3'})
    if salary:
        salary = salary.text
        min_salary, max_salary, currency_salary = clean_salary(salary)
    else:
        min_salary, max_salary, currency_salary = None, None, None

    link = vacancy.find('a')['href']
  
    return {
        'name': name,
        'salary': salary,
        'min_salary': min_salary,
        'max_salary': max_salary,
        'currency_salary': currency_salary,
        'link': link,
        'source': 'https://hh.ru/',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
    list_salary = vacancy_salary_text.replace('\u202f', '').split()
    for i in range(len(list_salary) - 1):
        if list_salary[i] == 'от':
            min_salary = int(list_salary[i + 1])
        elif list_salary[i] == 'до':
            max_salary = int(list_salary[i + 1])
        elif list_salary[i] == '-':
            min_salary = int(list_salary[i - 1])
            max_salary = int(list_salary[i + 1])
        currency_salary = list_salary[-1]

    return min_salary, max_salary, currency_salary

# %%
job = parse_hh('https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20', 
               headers=headers)

# %%
len(job)
# Out:
# 177

# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client.jobs

# %%
collection_jobs = db.hh_ru

# %%
def check_new_job(vacancies):
    for vacancy in vacancies:
        if not len(list(collection_jobs.find({'link': vacancy['link']}))):
            collection_jobs.insert_one(vacancy)

# %%
check_new_job(job)

# %%
len(list(collection_jobs.find()))
# Out:
# 177

# %%
for job in collection_jobs.find():
    pprint(job, sort_dicts=False)
# Out:
# {'_id': ObjectId('640b5a5b61508961a1cf5ab3'),
#  'name': 'Программист/Python-разработчик',
#  'salary': '50\u202f000 – 70\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77901810?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab4'),
#  'name': 'Team Lead Python',
#  'salary': 'от 400\u202f000 руб.',
#  'min_salary': 400000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77732509?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab5'),
#  'name': 'Python-разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77705925?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab6'),
#  'name': 'Ведущий Python-developer',
#  'salary': '240\u202f000 – 300\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77902515?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab7'),
#  'name': 'Middle Python developer (Казань)',
#  'salary': 'от 160\u202f000 руб.',
#  'min_salary': 160000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76115939?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab8'),
#  'name': 'Lead Python developer',
#  'salary': 'до 500\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 500000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77337810?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ab9'),
#  'name': 'Python-разработчик в команду автоматизации клиентской поддержки Еды',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77846378?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aba'),
#  'name': 'Преподаватель по программированию (Scratch, Python, Roblox)',
#  'salary': 'до 60\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 60000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77834181?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5abb'),
#  'name': 'Python Developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76843829?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5abc'),
#  'name': 'Разработчик Python',
#  'salary': 'от 120\u202f000 руб.',
#  'min_salary': 120000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76076341?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5abd'),
#  'name': 'Python senior developer (разработчик)',
#  'salary': 'от 250\u202f000 руб.',
#  'min_salary': 250000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76840136?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5abe'),
#  'name': 'Python разработчик (Middle)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77731486?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5abf'),
#  'name': 'Python Developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76597591?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac0'),
#  'name': 'Аналитик данных',
#  'salary': 'от 2\u202f000 USD',
#  'min_salary': 2000,
#  'max_salary': None,
#  'currency_salary': 'USD',
#  'link': 'https://spb.hh.ru/vacancy/77497476?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac1'),
#  'name': 'Python разработчик (Middle/Senior)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75627492?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac2'),
#  'name': 'Главный разработчик Python',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77885284?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac3'),
#  'name': 'Python backend-разработчик в команду Data Science',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77050357?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac4'),
#  'name': 'Системный аналитик (systems analyst)',
#  'salary': 'от 120\u202f000 руб.',
#  'min_salary': 120000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77145441?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac5'),
#  'name': 'Python разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77409819?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac6'),
#  'name': 'Системный администратор Linux (Казань)',
#  'salary': 'от 180\u202f000 руб.',
#  'min_salary': 180000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76115945?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac7'),
#  'name': 'Ведущий инженер-программист (python, С/C++)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76919357?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac8'),
#  'name': 'Преподаватель Python',
#  'salary': 'от 125\u202f000 руб.',
#  'min_salary': 125000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77083921?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ac9'),
#  'name': 'Python-разработчик (middle)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77289628?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aca'),
#  'name': 'Middle программист Python (платежные сервисы)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75552925?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5acb'),
#  'name': 'Инженер - исследователь (Data Science)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77129293?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5acc'),
#  'name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77585729?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5acd'),
#  'name': 'Full Stack (Python+Vue) Developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77752950?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ace'),
#  'name': 'Senior Python-разработчик в Контур.Тревел',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77707065?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5acf'),
#  'name': 'Разработчик/аналитик хранилищ данных (Общеплатформенные сервисы)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77621497?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad0'),
#  'name': 'Senior Python разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76287301?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad1'),
#  'name': 'Data-инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76888795?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad2'),
#  'name': 'Data Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76327290?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad3'),
#  'name': 'Senior/Lead Python-разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76921593?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad4'),
#  'name': 'Программист Python',
#  'salary': '110\u202f000 – 130\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77774266?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad5'),
#  'name': 'Программист',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76974239?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad6'),
#  'name': 'Системный администратор серверов Linux (удаленно)',
#  'salary': '230\u202f000 – 230\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76505079?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad7'),
#  'name': 'Системный инженер Linux',
#  'salary': 'от 75\u202f000 руб.',
#  'min_salary': 75000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77583238?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad8'),
#  'name': 'Специалист (администратор) ИТ/ГИС систем',
#  'salary': 'от 90\u202f000 руб.',
#  'min_salary': 90000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77895950?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ad9'),
#  'name': 'Преподаватель программирования в онлайн школу',
#  'salary': '50\u202f000 – 60\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77818730?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ada'),
#  'name': 'Специалист по внедрению информационных систем / ГИС-инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77496843?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5adb'),
#  'name': 'Технический писатель со знанием IT',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77768450?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5adc'),
#  'name': 'DevOps инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75684741?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5add'),
#  'name': 'Инженер-программист в группу техподдержки продукта Naumen Service '
#          'Desk',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77145210?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ade'),
#  'name': 'Технический писатель со знанием IT',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77761116?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5adf'),
#  'name': 'Специалист по информационной безопасности (ФинТех)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77091039?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae0'),
#  'name': 'Специалист службы поддержки с техническими знаниями (TOOLS)',
#  'salary': '15\u202f000 – 39\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/73595107?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae1'),
#  'name': 'Devops Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/74267896?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae2'),
#  'name': 'Senior Data Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77722193?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae3'),
#  'name': 'Go-разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76749089?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae4'),
#  'name': 'Senior fullstack разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77088713?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae5'),
#  'name': 'DevOps инженер (Брокерский бизнес)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77812344?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae6'),
#  'name': 'Инженер по сопровождению КХД',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77217236?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae7'),
#  'name': 'Аналитик по безопасной разработке ПО (DevSecOps)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77724803?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae8'),
#  'name': 'Ночной специалист службы поддержки с техническими знаниями (Браузер)',
#  'salary': '18\u202f000 – 45\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77769040?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5ae9'),
#  'name': 'Системный аналитик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75558913?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aea'),
#  'name': 'Team lead группы разработки',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77321225?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aeb'),
#  'name': 'Разработчик встроенного микропрограммного обеспечения',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77471496?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aec'),
#  'name': 'Старший аналитик SOC (L2)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77809751?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aed'),
#  'name': 'Senior С++ Developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75713615?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aee'),
#  'name': 'Продуктовый аналитик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77817254?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aef'),
#  'name': 'Инженер данных (качество сервисов,SLA)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/70972873?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af0'),
#  'name': 'DevOps Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77731033?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af1'),
#  'name': 'Младший системный администратор',
#  'salary': 'от 30\u202f000 руб.',
#  'min_salary': 30000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77383024?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af2'),
#  'name': 'Портфельный риск-менеджер по разработке стратегии взыскания',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77491579?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af3'),
#  'name': 'Инженер по безопасной разработке (AppSec инженер)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77706305?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af4'),
#  'name': 'PHP-разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/74123858?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af5'),
#  'name': 'Специалист службы поддержки с техническими знаниями (Волкер)',
#  'salary': '15\u202f000 – 39\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77489037?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af6'),
#  'name': 'Разработчик Java',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76783042?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af7'),
#  'name': 'Аналитик рынка',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/73407362?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af8'),
#  'name': 'Lead CRM Manager',
#  'salary': '1\u202f500 – 4\u202f000 USD',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'USD',
#  'link': 'https://spb.hh.ru/vacancy/77792893?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5af9'),
#  'name': 'Middle/Senior QA Mobile (Manual) / Тестировщик ПО',
#  'salary': 'от 150\u202f000 руб.',
#  'min_salary': 150000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77224947?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5afa'),
#  'name': 'Бизнес-аналитик (Операционный маркетинг)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/71039387?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5afb'),
#  'name': 'Аналитик данных по направлению взыскания (моделист)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77491070?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5afc'),
#  'name': 'BIM Координатор (Конструктивные решения)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76162174?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5afd'),
#  'name': 'Руководитель направления безопасности кода',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/74273857?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5afe'),
#  'name': 'Менеджер вводных уроков / пробных занятий (онлайн школа)',
#  'salary': '40\u202f000 – 120\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77022281?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5aff'),
#  'name': 'Архитектор ИС',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77850640?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b00'),
#  'name': 'Ведущий инженер АСУ ТП',
#  'salary': '110\u202f000 – 150\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/69316211?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b01'),
#  'name': 'Главный эксперт (Департамент стратегии, инноваций и маркетинга)',
#  'salary': 'от 65\u202f000 руб.',
#  'min_salary': 65000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77711309?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b02'),
#  'name': 'Преподаватель-практик лабораторного химического анализа',
#  'salary': 'до 125\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 125000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77695404?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b03'),
#  'name': 'Педагог (преподаватель) по программированию',
#  'salary': 'от 22\u202f000 руб.',
#  'min_salary': 22000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77650562?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b04'),
#  'name': 'Инженер-Конструктор ПГС (AUTODESK REVIT)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/54687546?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b05'),
#  'name': 'Аналитик на внутренние проекты',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77642212?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b06'),
#  'name': 'Заведующий сектором пространственных данных (г. Салехард, ЯНАО)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76794324?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b07'),
#  'name': 'Корпоративный психолог в Алабуга Политех',
#  'salary': '80\u202f000 – 90\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77767730?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b08'),
#  'name': 'Senior C++ разработчик в Поиск',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76073280?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b09'),
#  'name': 'Разработчик Creatio',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77581156?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0a'),
#  'name': 'Ведущий программист DS',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77321279?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0b'),
#  'name': 'Системный администратор',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77444139?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0c'),
#  'name': 'Specialist DevOps',
#  'salary': 'до 280\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 280000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/69142942?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0d'),
#  'name': 'Системный Аналитик',
#  'salary': 'от 90\u202f000 руб.',
#  'min_salary': 90000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77406922?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0e'),
#  'name': 'Golang разработчик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76725570?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b0f'),
#  'name': 'Педагог дополнительного образования',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77592634?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b10'),
#  'name': 'Системный администратор Linux',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77609301?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b11'),
#  'name': 'Инженер АСУ ТП',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77476535?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b12'),
#  'name': 'QA automation engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77725448?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b13'),
#  'name': 'Senior Software Design Engineer in Test (Python)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77207602?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b14'),
#  'name': 'Аналитик портфеля розничных кредитов',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76710627?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b15'),
#  'name': 'Бизнес-аналитик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/73882541?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b16'),
#  'name': 'Инженер DevOps',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77155085?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b17'),
#  'name': 'Руководитель группы сетевых инженеров ccnp',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77530463?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b18'),
#  'name': 'Преподаватель онлайн-курсов Python для детей (индивидуальные '
#          'занятия)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77686082?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b19'),
#  'name': 'Senior DevOps Engineer',
#  'salary': 'до 180\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 180000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77114181?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1a'),
#  'name': 'Инженер-конструктор 2 категории (Группа расчетов компрессоров)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77339268?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1b'),
#  'name': 'Финансовый менеджер',
#  'salary': '30\u202f000 – 50\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77723410?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1c'),
#  'name': 'Аналитик по сетевой безопасности',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75936842?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1d'),
#  'name': 'Ведущий специалист отдела виртуализации',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77130858?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1e'),
#  'name': 'Руководитель группы разработки С++',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76954547?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b1f'),
#  'name': 'Руководитель группы разработки С++',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76954494?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b20'),
#  'name': 'Техлид / Tech Lead BigData',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/75747550?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b21'),
#  'name': 'DevOps инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76503776?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b22'),
#  'name': 'Application security specialist',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76539544?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b23'),
#  'name': 'Системный администратор 2 линия',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/69369250?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b24'),
#  'name': 'Ведущий инженер АСУ ТП Yokogawa (Centum, Prosafe, Stardom)',
#  'salary': 'от 120\u202f000 руб.',
#  'min_salary': 120000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/55056476?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b25'),
#  'name': 'ML Engineer (Computer Vision)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76558811?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b26'),
#  'name': 'Ведущий инженер АСУТП (ПТК DeltaV)',
#  'salary': 'от 120\u202f000 руб.',
#  'min_salary': 120000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/69316288?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b27'),
#  'name': 'ML Engineer (Natural Language Processing)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76561183?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b28'),
#  'name': 'Инженер по внедрению и техподдержке телекоммуникационного биллинга '
#          '(удаленно)',
#  'salary': 'до 170\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 170000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77611405?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b29'),
#  'name': 'Инженер по тестированию',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77619088?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2a'),
#  'name': 'Эксперт в Команду "Чат-бот"',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76911066?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2b'),
#  'name': 'C++ Developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77583224?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2c'),
#  'name': 'Разработчик баз данных (PostgreSQL)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77556504?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2d'),
#  'name': 'Инженер-программист (BI, Qlik Sense)',
#  'salary': '40\u202f000 – 60\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77528497?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2e'),
#  'name': 'Руководитель направления отдела мониторинга и реагирования на '
#          'инциденты ИБ (SOC L2)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77516429?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b2f'),
#  'name': 'Специалист по Data Science',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77484387?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b30'),
#  'name': 'DevOps инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77296876?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b31'),
#  'name': 'Backend разработчик С++ в команду Транспорта',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/72747031?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b32'),
#  'name': 'QA automation (R&D)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/74246182?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b33'),
#  'name': 'Разработчик С++ в команду 3D Карта',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76073156?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b34'),
#  'name': 'Data Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76442309?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b35'),
#  'name': 'Аналитик sql',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77414687?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b36'),
#  'name': 'Backend программист',
#  'salary': 'от 130\u202f000 руб.',
#  'min_salary': 130000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77415978?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b37'),
#  'name': 'Кредитный аналитик Sql',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77416119?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b38'),
#  'name': 'DevOps-инженер (Казань)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/66729881?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b39'),
#  'name': 'Middle QA-инженер в команду Online',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77440901?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3a'),
#  'name': 'QA automation',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77416985?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3b'),
#  'name': 'QA-инженер (автоматизация)',
#  'salary': 'до 250\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 250000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77426116?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3c'),
#  'name': 'Системный администратор Linux',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/73081919?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3d'),
#  'name': 'Middle/Senior Computer Vision Engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77398262?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3e'),
#  'name': 'Специалист группы сопровождения биллинга',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76733886?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b3f'),
#  'name': 'Технический директор/СТО',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77436223?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b40'),
#  'name': 'Консультант 1С',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/74378411?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b41'),
#  'name': 'DWH разработчик / DWH инженер / Data Engineer',
#  'salary': 'от 110\u202f000 руб.',
#  'min_salary': 110000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76291842?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b42'),
#  'name': 'Продуктовый аналитик',
#  'salary': 'от 80\u202f000 руб.',
#  'min_salary': 80000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76283804?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b43'),
#  'name': 'QA mobile / Инженер по тестированию (manual/auto) в Тинькофф '
#          'Мобильный Банк',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76266218?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b44'),
#  'name': 'Инженер Linux',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/54220301?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b45'),
#  'name': 'Trading Platform Reliability Engineer',
#  'salary': 'от 1\u202f000 USD',
#  'min_salary': 1000,
#  'max_salary': None,
#  'currency_salary': 'USD',
#  'link': 'https://spb.hh.ru/vacancy/76095405?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b46'),
#  'name': 'QA automation engineer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77328098?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b47'),
#  'name': 'Специалист по тестированию на проникновение (pentest)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76272121?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b48'),
#  'name': 'Разработчик Asyncio, AioHttp уровня Middle',
#  'salary': '130\u202f000 – 190\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77282299?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b49'),
#  'name': 'Аналитик бизнес процессов',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76279241?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4a'),
#  'name': 'Разработчик SCADA-систем (C#, Python)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77277225?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4b'),
#  'name': 'Product Owner',
#  'salary': '220\u202f000 – 350\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77334460?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4c'),
#  'name': 'Аналитик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77287075?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4d'),
#  'name': 'Маркетолог-аналитик',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/73407335?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4e'),
#  'name': 'DevOps инженер',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/73776674?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b4f'),
#  'name': 'Руководитель группы разработки (Team Lead)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77224953?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b50'),
#  'name': 'Инженер-программист',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/72754447?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b51'),
#  'name': 'Внутренний аудитор (крупное промышленное производство)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77176522?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b52'),
#  'name': 'HR Аналитик',
#  'salary': 'от 70\u202f000 руб.',
#  'min_salary': 70000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/77111054?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b53'),
#  'name': 'DevOps-инженер (middle/senior, kubernetes)',
#  'salary': '100\u202f000 – 150\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76655413?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b54'),
#  'name': 'Аналитик данных',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77079684?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b55'),
#  'name': 'Руководитель направления HR аналитики',
#  'salary': 'от 150\u202f000 руб.',
#  'min_salary': 150000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76145094?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b56'),
#  'name': 'QA engineer (auto + manual)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/77005657?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b57'),
#  'name': 'Аналитик по информационной безопасности (vulnerability management)',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/72191481?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b58'),
#  'name': 'Старший системный администратор Linux',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76974868?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b59'),
#  'name': 'Data Analyst',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/71833309?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5a'),
#  'name': 'Специалист по тестированию / QA engineer (Junior)',
#  'salary': 'от 40\u202f000 руб.',
#  'min_salary': 40000,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76968641?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5b'),
#  'name': 'Аналитик данных',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/72306121?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5c'),
#  'name': 'ETL developer',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76536219?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5d'),
#  'name': 'Инженер по нагрузочному тестированию',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76919325?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5e'),
#  'name': 'QA Manual middle',
#  'salary': 'до 150\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 150000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76940164?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b5f'),
#  'name': 'Маркетолог',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76998906?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b60'),
#  'name': 'Менеджер проекта',
#  'salary': '150\u202f000 – 320\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76910722?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b61'),
#  'name': 'Программист-тестировщик (отдел автотестирования)',
#  'salary': '46\u202f000 – 92\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/75786851?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b62'),
#  'name': 'Программист-разработчик систем САУ',
#  'salary': 'до 200\u202f000 руб.',
#  'min_salary': None,
#  'max_salary': 200000,
#  'currency_salary': 'руб.',
#  'link': 'https://spb.hh.ru/vacancy/76817912?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}
# {'_id': ObjectId('640b5a5b61508961a1cf5b63'),
#  'name': 'Программист роботов',
#  'salary': None,
#  'min_salary': None,
#  'max_salary': None,
#  'currency_salary': None,
#  'link': 'https://spb.hh.ru/vacancy/76793294?from=vacancy_search_list&query=python',
#  'source': 'https://hh.ru/'}

# %%
def salary_enough_for_my_greed(collection, salary, currency):
    enough = []
    for element in collection.find():
        try:
            if element['currency_salary'] == currency and (element['min_salary'] > salary or element['max_salary'] > salary):
                enough.append(element)
        except TypeError:
            pass
            
    return enough

# %%
salary_enough_for_my_greed(collection_jobs, 250000, 'руб.')
# Out:
# [{'_id': ObjectId('640b5a5b61508961a1cf5ab4'),
#   'name': 'Team Lead Python',
#   'salary': 'от 400\u202f000 руб.',
#   'min_salary': 400000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'link': 'https://spb.hh.ru/vacancy/77732509?from=vacancy_search_list&query=python',
#   'source': 'https://hh.ru/'}]
