# %%
import requests
from bs4 import BeautifulSoup as bs
from time import sleep
import pandas as pd

# %%
headers = {
    'User-Agent': 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

# %%
def parse_hh(url, headers, pages=[], index_page=1):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return pages

    soup = bs(response.content, 'html.parser')
    vacancies = soup.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
        pages.append(parse_vacancy_hh(vacancy))

    link_next_page = soup.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
        link_next_page =  'https://spb.hh.ru' + link_next_page['href']
    else:
        return pages

    pages = parse_hh(link_next_page, headers, pages, index_page + 1)   
    return pages
     
def parse_vacancy_hh(vacancy):
    sleep(.1)
    name = vacancy.find('a').text

    salary = vacancy.find('span', {'class', 'bloko-header-section-3'})
    if salary:
        salary = salary.text
        min_salary, max_salary, currency_salary = clean_salary(salary)
    else:
        min_salary, max_salary, currency_salary = None, None, None

    link = vacancy.find('a')['href']
  
    return {
        'name': name,
        'salary': salary,
        'min_salary': min_salary,
        'max_salary': max_salary,
        'currency_salary': currency_salary,
        'link': link,
        'source': 'https://hh.ru/',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
    list_salary = vacancy_salary_text.replace('\u202f', '').split()
    for i in range(len(list_salary) - 1):
        if list_salary[i] == 'от':
            min_salary = int(list_salary[i + 1])
        elif list_salary[i] == 'до':
            max_salary = int(list_salary[i + 1])
        elif list_salary[i] == '-':
            min_salary = int(list_salary[i - 1])
            max_salary = int(list_salary[i + 1])
        currency_salary = list_salary[-1]

    return min_salary, max_salary, currency_salary

# %%
job = parse_hh('https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20', headers)

# %%
len(job)
# Out:
# 187

# %%
for vacancy in job:
    print(f'{vacancy["name"]}')
    print(f'minimum salary {vacancy["min_salary"]}')
    print(f'maximum salary {vacancy["max_salary"]}')
    print(f'currency_salary {vacancy["currency_salary"]}')
    print(f'link {vacancy["link"]}')
    print(f'source {vacancy["source"]}')
    print()
# Out:
# Программист Python
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/77774266?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Team Lead Python
# minimum salary 400000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/77732509?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python-разработчик
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77705925?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Middle Python developer (Казань)
# minimum salary 160000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76115939?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Junior/Middle Backend-разработчик на Ruby
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76964796?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Lead Python developer
# minimum salary None
# maximum salary 500000
# currency_salary руб.
# link https://spb.hh.ru/vacancy/77337810?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Разработчик Python
# minimum salary 120000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76076341?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python Developer
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76597591?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Аналитик данных
# minimum salary 2000
# maximum salary None
# currency_salary USD
# link https://spb.hh.ru/vacancy/77497476?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python разработчик (Middle)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77731486?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python Developer
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76843829?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python senior developer (разработчик)
# minimum salary 250000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76840136?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python разработчик
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77409819?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python backend-разработчик в команду Data Science
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77050357?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Ведущий инженер-программист (python, С/C++)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76919357?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный администратор Linux (Казань)
# minimum salary 180000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76115945?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный аналитик (systems analyst)
# minimum salary 120000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/77145441?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python разработчик
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/75951525?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Преподаватель Python
# minimum salary 125000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/77083921?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Python-разработчик (middle)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77289628?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный администратор Linux (Казань)
# minimum salary 180000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76115945?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Аналитик портфеля розничных кредитов
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76710627?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Технический писатель со знанием IT
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/77768450?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Специалист службы поддержки с техническими знаниями (TOOLS)
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/73595107?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Специалист по информационной безопасности (ФинТех)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/
from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Специалист по тестированию / QA engineer (Junior)
# minimum salary 40000
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76968641?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Аналитик данных
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/72306121?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# ETL developer
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76536219?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Инженер по нагрузочному тестированию
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76919325?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# QA Manual middle
# minimum salary None
# maximum salary 150000
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76940164?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Разработчик ETL
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76888773?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Маркетолог
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76998906?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Менеджер проекта
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76910722?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# DevOps инженер
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/75684741?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный администратор серверов Linux (удаленно)
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76505079?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Программист-тестировщик (отдел автотестирования)
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/75786851?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Программист-разработчик систем САУ
# minimum salary None
# maximum salary 200000
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76817912?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Программист роботов
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76793294?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# DevOps инженер (Junior)
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76767021?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Разработчик в тестировании / SDET (Java)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76771245?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Go-разработчик
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76749089?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный аналитик
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/75558913?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Data engineer (middle)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76715247?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Автор работ по программированию / программист
# minimum salary None
# maximum salary 90000
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76670173?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный администратор (инженер по внедрению)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76720819?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный администратор Linux
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/74406735?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# DevOps инженер (Брокерский бизнес)
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76642389?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Системный аналитик
# minimum salary None
# maximum salary None
# currency_salary руб.
# link https://spb.hh.ru/vacancy/76652169?from=vacancy_search_list&query=python
# source https://hh.ru/
#
# Ведущий QA инженер
# minimum salary None
# maximum salary None
# currency_salary None
# link https://spb.hh.ru/vacancy/76637802?from=vacancy_search_list&query=python
# source https://hh.ru/

# %%
job_df = pd.DataFrame(job)
job_df
# Out:
#                                                name                  salary  \
# 0                                Программист Python  110 000 – 130 000 руб.
# 1                                  Team Lead Python         от 400 000 руб.
# 2                                Python-разработчик                    None
# 3                  Middle Python developer (Казань)         от 160 000 руб.
# 4         Junior/Middle Backend-разработчик на Ruby  110 000 – 150 000 руб.
# ..                                              ...                     ...
# 182  Системный администратор (инженер по внедрению)                    None
# 183                   Системный администратор Linux                    None
# 184              DevOps инженер (Брокерский бизнес)                    None
# 185                              Системный аналитик  100 000 – 200 000 руб.
# 186                              Ведущий QA инженер                    None
#
#      min_salary  max_salary currency_salary  \
# 0           NaN         NaN            руб.
# 1      400000.0         NaN            руб.
# 2           NaN         NaN            None
# 3      160000.0         NaN            руб.
# 4           NaN         NaN            руб.
# ..          ...         ...             ...
# 182         NaN         NaN            None
# 183         NaN         NaN            None
# 184         NaN         NaN            None
# 185         NaN         NaN            руб.
# 186         NaN         NaN            None
#
#                                                   link          source
# 0    https://spb.hh.ru/vacancy/77774266?from=vacanc...  https://hh.ru/
# 1    https://spb.hh.ru/vacancy/77732509?from=vacanc...  https://hh.ru/
# 2    https://spb.hh.ru/vacancy/77705925?from=vacanc...  https://hh.ru/
# 3    https://spb.hh.ru/vacancy/76115939?from=vacanc...  https://hh.ru/
# 4    https://spb.hh.ru/vacancy/76964796?from=vacanc...  https://hh.ru/
# ..                                                 ...             ...
# 182  https://spb.hh.ru/vacancy/76720819?from=vacanc...  https://hh.ru/
# 183  https://spb.hh.ru/vacancy/74406735?from=vacanc...  https://hh.ru/
# 184  https://spb.hh.ru/vacancy/76642389?from=vacanc...  https://hh.ru/
# 185  https://spb.hh.ru/vacancy/76652169?from=vacanc...  https://hh.ru/
# 186  https://spb.hh.ru/vacancy/76637802?from=vacanc...  https://hh.ru/
#
# [187 rows x 7 columns]

# %%
job_df.to_csv('job.csv', index=False)
